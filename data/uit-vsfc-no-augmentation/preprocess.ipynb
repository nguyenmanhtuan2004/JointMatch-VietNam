# %%
# read data 
import pandas as pd


df = pd.read_csv('train.csv')
df.head()
# Out:
#    label                                            content  \
# 0      3                                cô rất thân thiện .
# 1      2  nội dung ôn tập mà giảng viên cung cấp đầy đủ ...
# 2      1  theo thời khóa biểu hiện nay thì học thực hành...
# 3      3  cô giảng nhiệt tình , chỉ bài cho tụi em thì l...
# 4      2                          tăng hiệu suất máy tính .
#
#                                     back_translation  \
# 0                                cô rất thân thiện .
# 1  nội dung ôn tập mà giảng viên cung cấp đầy đủ ...
# 2  theo thời khóa biểu hiện nay thì học thực hành...
# 3  cô giảng nhiệt tình , chỉ bài cho tụi em thì l...
# 4                          tăng hiệu suất máy tính .
#
#                                          synonym_aug
# 0                                cô rất thân thiện .
# 1  nội dung ôn tập mà giảng viên cung cấp đầy đủ ...
# 2  theo thời khóa biểu hiện nay thì học thực hành...
# 3  cô giảng nhiệt tình , chỉ bài cho tụi em thì l...
# ...

# %%
df['back_translation']=df['content']
df['synonym_aug']=df['content']
df.to_csv('train.csv', index=False)
